# %% [markdown]
# # Importing necessary libraries

# %%
# Importing necessary libraries
import pandas as pd
import tensorflow as tf
import re

import spacy
from tqdm.notebook import tqdm
from tensorflow.keras.utils import to_categorical
import numpy as np

# from sklearn.linear_model import LogisticRegression
# from sklearn.svm import LinearSVC
# from sklearn.tree import DecisionTreeClassifier
# from sklearn.ensemble import RandomForestClassifier
# from sklearn.naive_bayes import GaussianNB
# from sklearn.neighbors import KNeighborsClassifier

# from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score

from nltk.corpus import stopwords
from numpy import array
from nltk.tokenize import word_tokenize
from tensorflow import keras
from keras.preprocessing.text import one_hot,Tokenizer
# from keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.utils import pad_sequences
from keras.models import Sequential
from keras.layers.core import Activation, Dropout,Dense
from tensorflow.keras.layers import Conv1D, Embedding,GlobalMaxPooling1D

# %% [markdown]
# # Uploading Dataset

# %%
# Importing the drive to google colab
from google.colab import drive
drive.mount('/gdrive')
# Out:
# Mounted at /gdrive

# %%
# Reading the 2016 training data set in a pandas dataframe
df_train_2016 = pd.read_csv ('/gdrive/MyDrive/Colab Notebooks/Advanced NLP/twitter-2016train-BD.txt',sep="\t",
                             names=['ID', 'topic','emotion','User text'])
df_train_2016
# Out:
#                       ID       topic   emotion  \
# 0     628949369883000832  @microsoft  negative
# 1     628976607420645377  @microsoft  negative
# 2     629023169169518592  @microsoft  negative
# 3     629179223232479232  @microsoft  negative
# 4     629226490152914944  @microsoft  positive
# ...                  ...         ...       ...
# 4304  639166904813223937     metlife  positive
# 4305  639295526995890177     metlife  positive
# 4306  639804828739346432     metlife  positive
# 4307  639855845958885376     metlife  positive
# 4308  641034340068143104     metlife  positive
#
#                                               User text
# 0     dear @Microsoft the newOoffice for Mac is grea...
# 1     @Microsoft how about you make a system that do...
# 2     I may be ignorant on this issue but... should ...
# 3     Thanks to @microsoft, I just may be switching ...
# 4     Microsoft, I may not prefer your gaming branch...
# ...                                                 ...
# 4304   Heading up to MetLife tomorrow for the Jets game
# 4305  Going to MetLife tomorrow but not to see the b...
# 4306  It's the first Football Friday of the year. Th...
# 4307  @Racalto_SK ok good to know. Punting at MetLif...
# 4308  Mendez told me he'd drive me to MetLife on Sun...
#
# [4309 rows x 4 columns]

# %%
# Reading the 2016 dev data set in a pandas dataframe
df_dtrain_2016 = pd.read_csv ('/gdrive/MyDrive/Colab Notebooks/Advanced NLP/twitter-2016dev-BD.txt',sep="\t",
                             names=['ID', 'topic','emotion','User text'])
df_dtrain_2016
# Out:
#                       ID            topic   emotion  \
# 0     638061181823922176  michael jackson  positive
# 1     638091450132078593  michael jackson  positive
# 2     638125563790557184  michael jackson  positive
# 3     638130776727535617  michael jackson  positive
# 4     638134980862828544  michael jackson  positive
# ...                  ...              ...       ...
# 1285  640906424290254849       snoop dogg  positive
# 1286  640916034749263872       snoop dogg  positive
# 1287  641037652414742528       snoop dogg  positive
# 1288  641349309439479808       snoop dogg  positive
# 1289  641648318754516992       snoop dogg  positive
#
#                                               User text
# 0     Jay Z joins Instagram with nostalgic tribute t...
# 1     I liked a @YouTube video http://t.co/AaR3pjp2P...
# 2     18th anniv of Princess Diana's death. I still ...
# 3     @oridaganjazz The 1st time I heard Michael Jac...
# 4     'Michael Jackson' appeared on Saturday 29 at t...
# ...                                                 ...
# 1285  May something in life make you as happy as Sno...
# 1286  I need to become a celebrity so I can just be ...
# 1287         Snoop dogg may be the funniest human alive
# 1288  SNOOP DOGG AKA SNOOPADELIC friday friday only ...
# 1289  I can't stop thinking about the fact that I'm ...
#
# [1290 rows x 4 columns]

# %%
# Reading the 2016 testing data set in a pandas dataframe
df_test_2016 = pd.read_csv ('/gdrive/MyDrive/Colab Notebooks/Advanced NLP/twitter-2016test-BD.txt',sep="\t",
                            names=['ID', 'topic','emotion','User text','empty row'])
df_test_2016
# Out:
#                        ID        topic   emotion  \
# 0      681563394940473347  amy schumer  negative
# 1      675847244747177984  amy schumer  negative
# 2      672827854279843840  amy schumer  negative
# 3      662755012129529858  amy schumer  negative
# 4      671502639671042048  amy schumer  negative
# ...                   ...          ...       ...
# 10546  638032969383309312         zayn  positive
# 10547  634711870570500096         zayn  positive
# 10548  637134671797690368         zayn  positive
# 10549  636413565780557824         zayn  positive
# 10550  634633336124776448         zayn  positive
#
#                                                User text  empty row
# 0      @MargaretsBelly Amy Schumer is the stereotypic...        NaN
# 1      @dani_pitter I mean I get the hype around JLaw...        NaN
# 2      Amy Schumer at the #GQmenoftheyear2015 party i...        NaN
# 3      Amy Schumer is on Sky Atlantic doing one of th...        NaN
# 4      Amy Schumer may have brought us Trainwreck, bu...        NaN
# ...                                                  ...        ...
# 10546  tomorrow I've to wake up  early so Zayn's erfo...        NaN
# 10547  with Zayn gone I can now definitively say that...        NaN
# 10548  yo don't ever say that! god forbid! may it not...        NaN
# 10549  you may call me a bad fan but I sobbed so hard...        NaN
# 10550  zayn's voice: c'mon guys you can do it, nobody...        NaN
#
# [10551 rows x 5 columns]

# %%
# Reading the 2016 dev testing data set in a pandas dataframe
df_dtest_2016 = pd.read_csv ('/gdrive/MyDrive/Colab Notebooks/Advanced NLP/twitter-2016devtest-BD.txt',sep="\t",
                             names=['ID', 'topic','emotion','User text'])
df_dtest_2016
# Out:
#                       ID   topic   emotion  \
# 0     637641175948763136    sony  positive
# 1     637666734300905472    sony  negative
# 2     637668142110654468    sony  positive
# 3     637708370129125377    sony  positive
# 4     637807521500020737    sony  negative
# ...                  ...     ...       ...
# 1412  638013292036923392  zlatan  positive
# 1413  638018562334916609  zlatan  positive
# 1414  638033582112534529  zlatan  positive
# 1415  638445576212754433  zlatan  positive
# 1416  640276909633486849  zlatan  negative
#
#                                               User text
# 0     @SeeMonterey LOST - Sony cell phone with holid...
# 1     Sony rewards app is like a lot of 19 y.o femal...
# 2     @fakethom Have android tab and don't use phone...
# 3     Finally I get my ps4 back I sent it to Sony ca...
# 4     @AskPlayStation Why won't u guys help me out?!...
# ...                                                 ...
# 1412  Zlatan is looking mighty attractive at the mom...
# 1413  Wonder if Zlatan will be a United player come ...
# 1414  Today United should have done better, the refe...
# 1415  Ok ed let's do this, Zlatan, greizmann and Lap...
# 1416  Rib injury for Zlatan against Russia is a big ...
#
# [1417 rows x 4 columns]

# %%
# Reading the 2015 training data set in a pandas dataframe
df_train_2015 = pd.read_csv ('/gdrive/MyDrive/Colab Notebooks/Advanced NLP/twitter-2015train-BD.txt',sep="\t",
                  names=['ID', 'topic','emotion','User text'])
df_train_2015
# Out:
#                      ID    topic   emotion  \
# 0    105121481662541824  #dexter   neutral
# 1    104319460143415296  #dexter  positive
# 2    103641916586999808  #dexter  positive
# 3    100544750414864384  #dexter   neutral
# 4    102220476499243008  #dexter   neutral
# ..                  ...      ...       ...
# 484  264204267370450944   denzel  positive
# 485  264184542305345537   denzel  positive
# 486  264243526005575680   denzel  positive
# 487  264191631325020160   denzel   neutral
# 488  264204783974490113   denzel   neutral
#
#                                              User text
# 0    I forgot how sad the first episode of the 5th ...
# 1    Oct. 2 is almost too far away for me to wait f...
# 2    (OFF TOPIC) - there is only 3 episodes on the ...
# 3    @iheardavoicesay is finally catching up to me ...
# 4    I downloaded the first season of #Dexter, gonn...
# ..                                                 ...
# 484  Cant wait to see \""Flight\"" on Saturday\u002...
# 485  Gotta go see Flight tomorrow Denzel is the gre...
# 486  Hey I wanna see Flight tomorrow with Denzel ol...
# 487  That movie Flight with Denzel looks really goo...
# 488  \""@bline803rasta: Mane I gotta see that Denze...
#
# [489 rows x 4 columns]

# %%
# Reading the 2015 testing data set in a pandas dataframe
df_test_2015 = pd.read_csv ('/gdrive/MyDrive/Colab Notebooks/Advanced NLP/twitter-2015test-BD.txt',sep="\t",
                            names=['ID', 'topic','emotion','User text','empty row'])
df_test_2015
# Out:
#                       ID          topic   emotion  \
# 0     522712800595300352  aaron rodgers   neutral
# 1     522559216645840897  aaron rodgers   neutral
# 2     522560839211962368  aaron rodgers   neutral
# 3     523065089977757696  aaron rodgers  negative
# 4     522563839305338880  aaron rodgers   neutral
# ...                  ...            ...       ...
# 2378  520957142816530432       younique  positive
# 2379  522889214036156417       younique   neutral
# 2380  521416045865992192       younique  positive
# 2381  522912399322394624       younique  positive
# 2382  520917627460661248       younique  positive
#
#                                               User text  empty row
# 0     I just cut a 25 second audio clip of Aaron Rod...        NaN
# 1     Tough loss for the Dolphins last Sunday in Mia...        NaN
# 2     I'm wearing my Aaron Rodgers jersey to the Cha...        NaN
# 3     @Espngreeny I'm a Fins fan, it's Friday, and A...        NaN
# 4     When girls become bandwagon fans of the Packer...        NaN
# ...                                                 ...        ...
# 2378  Check out the gorgeous products from Younique!...        NaN
# 2379  LADIES!  BULK ORDER GOES IN TOMORROW AT 10PM C...        NaN
# 2380  Here is something fun for you:  On the 14th, I...        NaN
# 2381  Get the best mascara in the industry here! Im ...        NaN
# 2382  Wakey Wakey! It's SATURDAY SHOPPING Day! Make ...        NaN
#
# [2383 rows x 5 columns]

# %%
# Concatinating both 2015 and 2016 test dataset to one
df_test = pd.concat([df_test_2016,df_test_2015], axis = 0)
df_test
# Out:
#                       ID        topic   emotion  \
# 0     681563394940473347  amy schumer  negative
# 1     675847244747177984  amy schumer  negative
# 2     672827854279843840  amy schumer  negative
# 3     662755012129529858  amy schumer  negative
# 4     671502639671042048  amy schumer  negative
# ...                  ...          ...       ...
# 2378  520957142816530432     younique  positive
# 2379  522889214036156417     younique   neutral
# 2380  521416045865992192     younique  positive
# 2381  522912399322394624     younique  positive
# 2382  520917627460661248     younique  positive
#
#                                               User text  empty row
# 0     @MargaretsBelly Amy Schumer is the stereotypic...        NaN
# 1     @dani_pitter I mean I get the hype around JLaw...        NaN
# 2     Amy Schumer at the #GQmenoftheyear2015 party i...        NaN
# 3     Amy Schumer is on Sky Atlantic doing one of th...        NaN
# 4     Amy Schumer may have brought us Trainwreck, bu...        NaN
# ...                                                 ...        ...
# 2378  Check out the gorgeous products from Younique!...        NaN
# 2379  LADIES!  BULK ORDER GOES IN TOMORROW AT 10PM C...        NaN
# 2380  Here is something fun for you:  On the 14th, I...        NaN
# 2381  Get the best mascara in the industry here! Im ...        NaN
# 2382  Wakey Wakey! It's SATURDAY SHOPPING Day! Make ...        NaN
#
# [12934 rows x 5 columns]

# %%
# Concatinating both 2015 and 2016 train dataset to one
df_train = pd.concat([df_train_2015,df_train_2016,df_dtrain_2016,df_dtest_2016],axis=0)
df_train
# Out:
#                       ID    topic   emotion  \
# 0     105121481662541824  #dexter   neutral
# 1     104319460143415296  #dexter  positive
# 2     103641916586999808  #dexter  positive
# 3     100544750414864384  #dexter   neutral
# 4     102220476499243008  #dexter   neutral
# ...                  ...      ...       ...
# 1412  638013292036923392   zlatan  positive
# 1413  638018562334916609   zlatan  positive
# 1414  638033582112534529   zlatan  positive
# 1415  638445576212754433   zlatan  positive
# 1416  640276909633486849   zlatan  negative
#
#                                               User text
# 0     I forgot how sad the first episode of the 5th ...
# 1     Oct. 2 is almost too far away for me to wait f...
# 2     (OFF TOPIC) - there is only 3 episodes on the ...
# 3     @iheardavoicesay is finally catching up to me ...
# 4     I downloaded the first season of #Dexter, gonn...
# ...                                                 ...
# 1412  Zlatan is looking mighty attractive at the mom...
# 1413  Wonder if Zlatan will be a United player come ...
# 1414  Today United should have done better, the refe...
# 1415  Ok ed let's do this, Zlatan, greizmann and Lap...
# 1416  Rib injury for Zlatan against Russia is a big ...
#
# [7505 rows x 4 columns]

# %%
df_test= df_test[df_test.columns.drop('empty row')]

# %%
# The samples of the training dataset
df_test.head()
# Out:
#                    ID        topic   emotion  \
# 0  681563394940473347  amy schumer  negative
# 1  675847244747177984  amy schumer  negative
# 2  672827854279843840  amy schumer  negative
# 3  662755012129529858  amy schumer  negative
# 4  671502639671042048  amy schumer  negative
#
#                                            User text
# 0  @MargaretsBelly Amy Schumer is the stereotypic...
# 1  @dani_pitter I mean I get the hype around JLaw...
# 2  Amy Schumer at the #GQmenoftheyear2015 party i...
# 3  Amy Schumer is on Sky Atlantic doing one of th...
# 4  Amy Schumer may have brought us Trainwreck, bu...

# %%
# The samples of the testing dataset
df_train.head()
# Out:
#                    ID    topic   emotion  \
# 0  105121481662541824  #dexter   neutral
# 1  104319460143415296  #dexter  positive
# 2  103641916586999808  #dexter  positive
# 3  100544750414864384  #dexter   neutral
# 4  102220476499243008  #dexter   neutral
#
#                                            User text
# 0  I forgot how sad the first episode of the 5th ...
# 1  Oct. 2 is almost too far away for me to wait f...
# 2  (OFF TOPIC) - there is only 3 episodes on the ...
# 3  @iheardavoicesay is finally catching up to me ...
# 4  I downloaded the first season of #Dexter, gonn...

# %%
import locale
def getpreferredencoding(do_setlocale = True):
    return "UTF-8"
locale.getpreferredencoding = getpreferredencoding

# %% [markdown]
# # **Preprocessing**

# %%
# intall emoji
# !pip install emoji
import emoji


def preprocess_tweet(tweet: str) -> str:

  tweet = tweet.lower() #convert all the tweets to lowercase
  tweet = emoji.demojize(tweet) #demojize tweet into phrases insead of an emoji

  tweet = re.sub("#[A-Za-z0-9_]+","", tweet) # removal of hastags
  tweet = re.sub("@[A-Za-z0-9_]+","", tweet) #removal of mentions
  tweet = re.sub('http://\S+|https://\S+', '', tweet) #removal of url
  tweet = re.sub(r'[\'|"|#|:|,|)|(|\|/|_]',r'',tweet) #removal of non alphabet characters
  tweet = " ".join(tweet.split()) #extra spaces

  return tweet
# Out:
# Collecting emoji
#   Downloading emoji-2.8.0-py2.py3-none-any.whl (358 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 358.9/358.9 kB 5.2 MB/s eta 0:00:00
# Installing collected packages: emoji
# Successfully installed emoji-2.8.0

# %%
df_train["Cleaned tweet"] = df_train["User text"].apply(preprocess_tweet)
df_test["Cleaned tweet"] = df_test["User text"].apply(preprocess_tweet)

# %% [markdown]
# # **POS tagging**

# %%
nlp = spacy.load("en_core_web_sm")

def generate_pos_features(tweet: str) -> str:
  """
  Input: A cleaned tweet Eg:"bag is amazing"
  output: A lemmatized tweet with pos tags to each token. Eg:"bag-NN is-VB amazing-JJ"
  """
  res_str2 =''
  res_str3 = ''
  l=[]

  tweet_tag = nlp(tweet)
  # res_str = ' '.join([token.lemma_ for token in tweet_tag])

  # abc = nlp(res_str)

  for token in tweet_tag:
    l.append(token.lemma_ + '-' +token.tag_)

    res_str2 = ' '.join(l)
  return res_str2



def generate_pos_features1(tweet: str) -> str:
  """
  Input: A cleaned tweet Eg:"bag is amazing"
  output: pos tags to each lemmatized token. Eg:"NN VB JJ"
  """
  res_str2 =''
  l=[]

  tweet_tag = nlp(tweet)
  # res_str = ' '.join([token.lemma_ for token in tweet_tag])

  # abc = nlp(res_str)

  for token in tweet_tag:
    l.append(token.tag_)
    res_str2 = ' '.join(l)
  return res_str2

# %%
# Applying PoS Tagging to Cleaned tweet of both training and testing dataset and storing it in a new column 'Tweet with pos'
df_train["Tweet with pos"]= df_train["Cleaned tweet"].apply(generate_pos_features)
df_test["Tweet with pos"]= df_test["Cleaned tweet"].apply(generate_pos_features)

# %%
# Applying PoS Tagging to Cleaned tweet of both training and testing dataset and storing it in a new column 'Only pos sequence'
df_train["Only pos sequence"]= df_train["Cleaned tweet"].apply(generate_pos_features1)
df_test["Only pos sequence"]= df_test["Cleaned tweet"].apply(generate_pos_features1)

# %%
df_train.tail()
# Out:
#                       ID   topic   emotion  \
# 1412  638013292036923392  zlatan  positive
# 1413  638018562334916609  zlatan  positive
# 1414  638033582112534529  zlatan  positive
# 1415  638445576212754433  zlatan  positive
# 1416  640276909633486849  zlatan  negative
#
#                                               User text  \
# 1412  Zlatan is looking mighty attractive at the mom...
# 1413  Wonder if Zlatan will be a United player come ...
# 1414  Today United should have done better, the refe...
# 1415  Ok ed let's do this, Zlatan, greizmann and Lap...
# 1416  Rib injury for Zlatan against Russia is a big ...
#
#                                           Cleaned tweet  \
# 1412  zlatan is looking mighty attractive at the mom...
# 1413  wonder if zlatan will be a united player come ...
# 1414  today united should have done better the refer...
# 1415  ok ed lets do this zlatan greizmann and laport...
# 1416  rib injury for zlatan against russia is a big ...
#
#                                          Tweet with pos  \
# 1412  zlatan-NNP be-VBZ look-VBG mighty-RB attractiv...
# 1413  wonder-VBP if-IN zlatan-NNP will-MD be-VB a-DT...
# 1414  today-NN united-NNP should-MD have-VB do-VBN w...
# 1415  ok-UH ed-NNP let-NNS do-VB this-DT zlatan-NNP ...
# 1416  rib-NN injury-NN for-IN zlatan-NNP against-IN ...
#
#                                       Only pos sequence
# 1412  NNP VBZ VBG RB JJ IN DT NN NNP VBZ RB VB DT NN...
# 1413  VBP IN NNP MD VB DT NNP NN VB NNP NN VBP PRP M...
# 1414  NN NNP MD VB VBN RBR DT NN VBD RB VB RB RB . ....
# 1415       UH NNP NNS VB DT NNP NNP CC NN NN VBP PRP VB
# 1416  NN NN IN NNP IN NNP VBZ DT JJ NN IN PRP VBZ NN...

# %%
df_test.tail()
# Out:
#                       ID     topic   emotion  \
# 2378  520957142816530432  younique  positive
# 2379  522889214036156417  younique   neutral
# 2380  521416045865992192  younique  positive
# 2381  522912399322394624  younique  positive
# 2382  520917627460661248  younique  positive
#
#                                               User text  \
# 2378  Check out the gorgeous products from Younique!...
# 2379  LADIES!  BULK ORDER GOES IN TOMORROW AT 10PM C...
# 2380  Here is something fun for you:  On the 14th, I...
# 2381  Get the best mascara in the industry here! Im ...
# 2382  Wakey Wakey! It's SATURDAY SHOPPING Day! Make ...
#
#                                           Cleaned tweet  \
# 2378  check out the gorgeous products from younique!...
# 2379  ladies! bulk order goes in tomorrow at 10pm cs...
# 2380  here is something fun for you on the 14th i am...
# 2381  get the best mascara in the industry here! im ...
# 2382  wakey wakey! its saturday shopping day! make s...
#
#                                          Tweet with pos  \
# 2378  check-VB out-RP the-DT gorgeous-JJ product-NNS...
# 2379  lady-NNS !-. bulk-JJ order-NN go-VBZ in-IN tom...
# 2380  here-RB be-VBZ something-NN fun-JJ for-IN you-...
# 2381  get-VB the-DT good-JJS mascara-NN in-IN the-DT...
# 2382  wakey-NN wakey-NN !-. its-PRP$ saturday-NNP sh...
#
#                                       Only pos sequence
# 2378  VB RP DT JJ NNS IN NN . VB PRP IN NNS CC NN IN...
# 2379  NNS . JJ NN VBZ IN NN IN CD NN NNP NNP CD JJR ...
# 2380  RB VBZ NN JJ IN PRP IN DT JJ PRP VBP VBG TO VB...
# 2381  VB DT JJS NN IN DT NN RB . PRP VBP VBG JJ NN I...
# 2382  NN NN . PRP$ NNP NNP NN . VB JJ TO VB PRP$ JJ ...

# %%
print('Positive tweets:',df_train['emotion'].value_counts()['positive'])
print('Negative tweets:',df_train['emotion'].value_counts()['negative'])
print('Neutral tweets:',df_train['emotion'].value_counts()['neutral'])
# Out:
# Positive tweets: 5802
# Negative tweets: 1412
# Neutral tweets: 288

# %% [markdown]
# # **Splitting the data-Training and Testing**

# %%
# splitting the training and testing data
y_train = df_train['emotion']
X_train= df_train[df_train.columns.drop('emotion')]

y_test = df_test['emotion']
X_test= df_test[df_train.columns.drop('emotion')]

# %%
'''Converting y training labels into number
          positive = 1
          Negative = -1
          Neutral = 0
'''
y =(list(y_train))
print(y)
for i in range(len(y)):
  if y[i] == 'positive':
    y[i]= 1
  elif y[i] =='negative':
    y[i] = -1
  else:
    y[i] = 0

y_train = np.array(y)
print(y_train)
type(y_train)
# Out:
# ['neutral', 'positive', 'positive', 'neutral', 'neutral', 'neutral', 'neutral', 'positive', 'positive', 'neutral', 'positive', 'positive', 'positive', 'positive', 'positive', 'positive', 'positive', 'neutral', 'positive', 'neutral', 'neutral', 'neutral', 'positive', 'positive', 'positive', 'positive', 'positive', 'negative', 'positive', 'neutral', 'negative', 'neutral', 'neutral', 'positive', 'neutral', 'positive', 'neutral', 'positive', 'positive', 'neutral', 'neutral', 'positive', 'positive', 'positive', 'positive', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'positive', 'neutral', 'positive', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'negative', 'neutral', 'negative', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'positive', 'positive', 'negative', 'negative', 'neutral', 'neutral', 'off topic', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'negative', 'positive', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'positive', 'negative', 'negative', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'positive', 'neutral', 'neutral', 'positive', 'neutral', 'neutral', 'neutral', 'positive', 'neutral', 'positive', 'positive', 'positive', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'positive', 'positive', 'positive', 'negative', 'negative', 'neutral', 'neutral', 'negative', 'neutral', 'negative', 'negative', 'negative', 'negative', 'positive', 'neutral', 'positive', 'positive', 'positive', 'positive', 'neutral', 'positive', 'positive', 'positive', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'positive', 'neutral', 'neutral', 'positive', 'positive', 'positive', 'positive', 'neutral', 'neutral', 'positive', 'neutral', 'positive', 'positive', 'neutral', 'positive', 'neutral', 'positive', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'negative', 'neutral', 'negative', 'negative', 'neutral', 'negative', 'negative', 'positive', 'neutral', 'neutral', 'neutral', 'neutral', 'negative', 'neutral', 'neutral', 'neutral', 'neutral', 'negative', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'positive', 'positive', 'neutral', 'positive', 'neutral', 'positive', 'neutral', 'negative', 'negative', 'neutral', 'neutral', 'positive', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'off topic', 'neutral', 'neutral', 'neutral', 'positive', 'neutral', 'positive', 'neutral', 'positive', 'neutral', 'neutral', 'positive', 'positive', 'positive', 'positive', 'neutral', 'positive', 'positive', 'negative', 'positive', 'positive', 'positive', 'positive', 'positive', 'positive', 'positive', 'positive', 'positive', 'positive', 'neutral', 'neutral', 'neutral', 'positive', 'positive', 'positive', 'positive', 'positive', 'positive', 'positive', 'positive', 'positive', 'positive', 'negative', 'positive', 'negative', 'negative', 'negative', 'positive', 'negative', 'positive', 'off topic', 'positive', 'positive', 'neutral', 'positive', 'neutral', 'positive', 'positive', 'positive', 'neutral', 'neutral', 'positive', 'negative', 'positive', 'neutral', 'positive', 'negative', 'neutral', 'neutral', 'neutral', 'neutral', 'positive', 'positive', 'positive', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'positive', 'positive', 'positive', 'negative', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'negative', 'negative', 'negative', 'neutral', 'neutral', 'neutral', 'negative', 'negative', 'negative', 'negative', 'negative', 'negative', 'neutral', 'neutral', 'neutral', ...
# numpy.ndarray
# [ 0  1  1 ...  1  1 -1]

# %%
'''Converting y testing labels into number
          positive = 1
          Negative = -1
          Neutral = 0
'''
y1 =(list(y_test))
for i in range(len(y1)):
  if y1[i] == 'positive':
    y1[i]= 1
  elif y1[i] =='negative':
    y1[i] = -1
  else:
    y1[i] = 0
y_test = np.array(y1)

# %%
y_train
# Out:
# array([ 0,  1,  1, ...,  1,  1, -1])

# %%
# Transforming y label to a categorical value
y_train = to_categorical(y_train, 3)
y_test = to_categorical(y_test, 3)

# %%
# Training samples
X_train.head()
# Out:
#                    ID    topic  \
# 0  105121481662541824  #dexter
# 1  104319460143415296  #dexter
# 2  103641916586999808  #dexter
# 3  100544750414864384  #dexter
# 4  102220476499243008  #dexter
#
#                                            User text  \
# 0  I forgot how sad the first episode of the 5th ...
# 1  Oct. 2 is almost too far away for me to wait f...
# 2  (OFF TOPIC) - there is only 3 episodes on the ...
# 3  @iheardavoicesay is finally catching up to me ...
# 4  I downloaded the first season of #Dexter, gonn...
#
#                                        Cleaned tweet  \
# 0  i forgot how sad the first episode of the 5th ...
# 1  oct. 2 is almost too far away for me to wait f...
# 2  off topic - there is only 3 episodes on the fi...
# 3  is finally catching up to me with . im only up...
# 4  i downloaded the first season of gonna start w...
#
#                                       Tweet with pos  \
# 0  I-PRP forget-VBD how-WRB sad-JJ the-DT first-J...
# 1  oct-NNP .-NNP 2-CD be-VBZ almost-RB too-RB far...
# 2  off-RP topic-NN --: there-EX be-VBZ only-RB 3-...
# 3  be-VBZ finally-RB catch-VBG up-RP to-IN I-PRP ...
# 4  I-PRP download-VBD the-DT first-JJ season-NN o...
#
#                                    Only pos sequence
# 0    PRP VBD WRB JJ DT JJ NN IN DT JJ NN IN NN VBZ .
# 1  NNP NNP CD VBZ RB RB RB RB IN PRP TO VB IN DT ...
# 2  RP NN : EX VBZ RB CD NNS IN DT JJ NN IN . UH V...
# 3  VBZ RB VBG RP IN PRP IN . PRP VBP RB IN TO NN ...
# 4  PRP VBD DT JJ NN IN NN TO VB VBG DT JJ NN . NN...

# %%
# Testing samples
X_test.head()
# Out:
#                    ID        topic  \
# 0  681563394940473347  amy schumer
# 1  675847244747177984  amy schumer
# 2  672827854279843840  amy schumer
# 3  662755012129529858  amy schumer
# 4  671502639671042048  amy schumer
#
#                                            User text  \
# 0  @MargaretsBelly Amy Schumer is the stereotypic...
# 1  @dani_pitter I mean I get the hype around JLaw...
# 2  Amy Schumer at the #GQmenoftheyear2015 party i...
# 3  Amy Schumer is on Sky Atlantic doing one of th...
# 4  Amy Schumer may have brought us Trainwreck, bu...
#
#                                        Cleaned tweet  \
# 0  amy schumer is the stereotypical 1st world lac...
# 1  i mean i get the hype around jlaw. i may not l...
# 2  amy schumer at the party in a dress we pretty ...
# 3  amy schumer is on sky atlantic doing one of th...
# 4  amy schumer may have brought us trainwreck but...
#
#                                       Tweet with pos  \
# 0  amy-NNP schumer-NNP be-VBZ the-DT stereotypica...
# 1  I-PRP mean-VBP I-PRP get-VBP the-DT hype-NN ar...
# 2  amy-NNP schumer-NN at-IN the-DT party-NN in-IN...
# 3  amy-NNP schumer-NN be-VBZ on-IN sky-NN atlanti...
# 4  amy-NNP schumer-NN may-MD have-VB bring-VBN we...
#
#                                    Only pos sequence
# 0  NNP NNP VBZ DT JJ NN NN NNP NNP NNP . CC PRP V...
# 1  PRP VBP PRP VBP DT NN IN NN . PRP MD RB VB PRP...
# 2             NNP NN IN DT NN IN DT NN PRP RB RB VBP
# 3  NNP NN VBZ IN NN JJ VBG CD IN DT JJS VB RP NNS...
# 4   NNP NN MD VB VBN PRP NN CC DT NN RB VBD VBN RP .

# %% [markdown]
# # DL Classifier CNN

# %% [markdown]
# ## Cleaned Tweet

# %%
# embedding layer

word_tokenizer = Tokenizer()
word_tokenizer.fit_on_texts(X_train)

x_train = word_tokenizer.texts_to_matrix(X_train['Cleaned tweet'])
x_test = word_tokenizer.texts_to_matrix(X_test['Cleaned tweet'])

# %%
vocab_len = len(word_tokenizer.word_index)+1
vocab_len
# Out:
# 11

# %%
maxlen = 100
x_train = pad_sequences(x_train,  padding ='post', maxlen =maxlen)
x_test = pad_sequences(x_test,  padding ='post', maxlen =maxlen)

# %%
# Extract the embeddings from the GloVe file
embeddings = dict()
glove_file = open('/gdrive/MyDrive/Colab Notebooks/Advanced NLP/glove.6B/glove.6B.100d.txt',encoding = "utf8")

for line in glove_file:
  records = line.split()
  word = records[0]
  vector_dimensions = np.asarray(records[1:],dtype ="float32")
  embeddings[word] = vector_dimensions

glove_file.close()

# %%
# Based on the pre-trained GloVe embeddings, create embeddings for the training and testing data
embedding_matrix  = np.zeros((vocab_len,100))
for word, index  in word_tokenizer.word_index.items():
  embeddings_vector = embeddings.get(word)
  if embeddings_vector is not None:
    embedding_matrix[index] = embeddings_vector

# %%
cnn = Sequential()
embedding = Embedding(vocab_len,100,weights =[embedding_matrix], input_length = maxlen, trainable = False)

cnn.add(embedding)
cnn.add(Conv1D(128, 5,activation = 'relu'))
cnn.add(GlobalMaxPooling1D())
cnn.add(Dense(units=64, activation='relu'))
cnn.add(Dropout(0.5))
cnn.add(Dense(units=64, activation='relu'))
cnn.add(Dropout(0.5))
cnn.add(Dense(3, activation = 'softmax'))

# %%
cnn.compile(optimizer='adam',loss = 'categorical_crossentropy', metrics=['acc'])
# model.build(shape)
print(cnn.summary())
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding (Embedding)       (None, 100, 100)          1100
#
#  conv1d (Conv1D)             (None, 96, 128)           64128
#
#  global_max_pooling1d (Globa  (None, 128)              0
#  lMaxPooling1D)
#
#  dense (Dense)               (None, 64)                8256
#
#  dropout (Dropout)           (None, 64)                0
#
#  dense_1 (Dense)             (None, 64)                4160
#
#  dropout_1 (Dropout)         (None, 64)                0
#
#  dense_2 (Dense)             (None, 3)                 195
#
# =================================================================
# Total params: 77,839
# Trainable params: 76,739
# Non-trainable params: 1,100
# _________________________________________________________________
# None

# %%
model_hist_cnn = cnn.fit(x_train,y_train,batch_size = 16, epochs =6,validation_split =0.2)
# Out:
# Epoch 1/6
# 376/376 [==============================] - 11s 24ms/step - loss: 0.7515 - acc: 0.7560 - val_loss: 0.5436 - val_acc: 0.8201
# Epoch 2/6
# 376/376 [==============================] - 7s 18ms/step - loss: 0.6948 - acc: 0.7613 - val_loss: 0.5166 - val_acc: 0.8201
# Epoch 3/6
# 376/376 [==============================] - 9s 25ms/step - loss: 0.6933 - acc: 0.7613 - val_loss: 0.5304 - val_acc: 0.8201
# Epoch 4/6
# 376/376 [==============================] - 13s 35ms/step - loss: 0.6798 - acc: 0.7613 - val_loss: 0.5190 - val_acc: 0.8201
# Epoch 5/6
# 376/376 [==============================] - 9s 25ms/step - loss: 0.6810 - acc: 0.7613 - val_loss: 0.5349 - val_acc: 0.8201
# Epoch 6/6
# 376/376 [==============================] - 8s 22ms/step - loss: 0.6789 - acc: 0.7613 - val_loss: 0.5264 - val_acc: 0.8201

# %%
score = cnn.evaluate(x_test,y_test)
# Out:
# 405/405 [==============================] - 9s 22ms/step - loss: 0.8145 - acc: 0.7019

# %% [markdown]
# ## Cleaned Tweet with POS

# %%
# embedding layer

word_tokenizer = Tokenizer()
word_tokenizer.fit_on_texts(X_train)

x_train = word_tokenizer.texts_to_matrix(X_train['Tweet with pos'])
x_test = word_tokenizer.texts_to_matrix(X_test['Tweet with pos'])

# %%
vocab_len = len(word_tokenizer.word_index)+1
vocab_len
# Out:
# 11

# %%
maxlen = 100
x_train = pad_sequences(x_train,  padding ='post', maxlen =maxlen)
x_test = pad_sequences(x_test,  padding ='post', maxlen =maxlen)

# %%
# Extract the embeddings from the GloVe file
embeddings = dict()
glove_file = open('/gdrive/MyDrive/Colab Notebooks/Advanced NLP/glove.6B/glove.6B.100d.txt',encoding = "utf8")

for line in glove_file:
  records = line.split()
  word = records[0]
  vector_dimensions = np.asarray(records[1:],dtype ="float32")
  embeddings[word] = vector_dimensions

glove_file.close()

# %%
# Based on the pre-trained GloVe embeddings, create embeddings for the training and testing data
embedding_matrix  = np.zeros((vocab_len,100))
for word, index  in word_tokenizer.word_index.items():
  embeddings_vector = embeddings.get(word)
  if embeddings_vector is not None:
    embedding_matrix[index] = embeddings_vector

# %%
cnn = Sequential()
embedding = Embedding(vocab_len,100,weights =[embedding_matrix], input_length = maxlen, trainable = False)

cnn.add(embedding)
cnn.add(Conv1D(128, 5,activation = 'relu'))
cnn.add(GlobalMaxPooling1D())
cnn.add(Dense(units=64, activation='relu'))
cnn.add(Dropout(0.5))
cnn.add(Dense(units=64, activation='relu'))
cnn.add(Dropout(0.5))
cnn.add(Dense(3, activation = 'softmax'))

# %%
cnn.compile(optimizer='adam',loss = 'categorical_crossentropy', metrics=['acc'])
# model.build(shape)
print(cnn.summary())
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding (Embedding)       (None, 100, 100)          1100
#
#  conv1d (Conv1D)             (None, 96, 128)           64128
#
#  global_max_pooling1d (Globa  (None, 128)              0
#  lMaxPooling1D)
#
#  dense (Dense)               (None, 64)                8256
#
#  dropout (Dropout)           (None, 64)                0
#
#  dense_1 (Dense)             (None, 64)                4160
#
#  dropout_1 (Dropout)         (None, 64)                0
#
#  dense_2 (Dense)             (None, 3)                 195
#
# =================================================================
# Total params: 77,839
# Trainable params: 76,739
# Non-trainable params: 1,100
# _________________________________________________________________
# None

# %%
model_hist_cnn = cnn.fit(x_train,y_train,batch_size = 16, epochs =6,validation_split =0.2)
# Out:
# Epoch 1/6
# 376/376 [==============================] - 7s 17ms/step - loss: 0.6735 - acc: 0.7613 - val_loss: 0.5264 - val_acc: 0.8201
# Epoch 2/6
# 376/376 [==============================] - 9s 23ms/step - loss: 0.6747 - acc: 0.7613 - val_loss: 0.5257 - val_acc: 0.8201
# Epoch 3/6
# 376/376 [==============================] - 7s 17ms/step - loss: 0.6731 - acc: 0.7613 - val_loss: 0.5189 - val_acc: 0.8201
# Epoch 4/6
# 376/376 [==============================] - 17s 46ms/step - loss: 0.6736 - acc: 0.7613 - val_loss: 0.5258 - val_acc: 0.8201
# Epoch 5/6
# 376/376 [==============================] - 12s 31ms/step - loss: 0.6727 - acc: 0.7613 - val_loss: 0.5198 - val_acc: 0.8201
# Epoch 6/6
# 376/376 [==============================] - 11s 31ms/step - loss: 0.6739 - acc: 0.7613 - val_loss: 0.5207 - val_acc: 0.8201

# %%
score = cnn.evaluate(x_test,y_test)
# Out:
# 405/405 [==============================] - 8s 20ms/step - loss: 0.8201 - acc: 0.7019

# %% [markdown]
# ## Only POS sequence

# %%
# embedding layer

word_tokenizer = Tokenizer()
word_tokenizer.fit_on_texts(X_train)

x_train = word_tokenizer.texts_to_matrix(X_train['Only pos sequence'])
x_test = word_tokenizer.texts_to_matrix(X_test['Only pos sequence'])

# %%
vocab_len = len(word_tokenizer.word_index)+1
vocab_len
# Out:
# 11

# %%
maxlen = 100
x_train = pad_sequences(x_train,  padding ='post', maxlen =maxlen)
x_test = pad_sequences(x_test,  padding ='post', maxlen =maxlen)

# %%
# Extract the embeddings from the GloVe file
embeddings = dict()
glove_file = open('/gdrive/MyDrive/Colab Notebooks/Advanced NLP/glove.6B/glove.6B.100d.txt',encoding = "utf8")

for line in glove_file:
  records = line.split()
  word = records[0]
  vector_dimensions = np.asarray(records[1:],dtype ="float32")
  embeddings[word] = vector_dimensions

glove_file.close()

# %%
# Based on the pre-trained GloVe embeddings, create embeddings for the training and testing data
embedding_matrix  = np.zeros((vocab_len,100))
for word, index  in word_tokenizer.word_index.items():
  embeddings_vector = embeddings.get(word)
  if embeddings_vector is not None:
    embedding_matrix[index] = embeddings_vector

# %%
cnn = Sequential()
embedding = Embedding(vocab_len,100,weights =[embedding_matrix], input_length = maxlen, trainable = False)

cnn.add(embedding)
cnn.add(Conv1D(128, 5,activation = 'relu'))
cnn.add(GlobalMaxPooling1D())
cnn.add(Dense(units=64, activation='relu'))
cnn.add(Dropout(0.5))
cnn.add(Dense(units=64, activation='relu'))
cnn.add(Dropout(0.5))
cnn.add(Dense(3, activation = 'softmax'))

# %%
cnn.compile(optimizer='adam',loss = 'categorical_crossentropy', metrics=['acc'])
# model.build(shape)
print(cnn.summary())
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding_1 (Embedding)     (None, 100, 100)          1100
#
#  conv1d_1 (Conv1D)           (None, 96, 128)           64128
#
#  global_max_pooling1d_1 (Glo  (None, 128)              0
#  balMaxPooling1D)
#
#  dense_3 (Dense)             (None, 64)                8256
#
#  dropout_2 (Dropout)         (None, 64)                0
#
#  dense_4 (Dense)             (None, 64)                4160
#
#  dropout_3 (Dropout)         (None, 64)                0
#
#  dense_5 (Dense)             (None, 3)                 195
#
# =================================================================
# Total params: 77,839
# Trainable params: 76,739
# Non-trainable params: 1,100
# _________________________________________________________________
# None

# %%
model_hist_cnn = cnn.fit(x_train,y_train,batch_size = 16, epochs =6,validation_split =0.2)
# Out:
# Epoch 1/6
# 376/376 [==============================] - 9s 22ms/step - loss: 0.7887 - acc: 0.7595 - val_loss: 0.5363 - val_acc: 0.8201
# Epoch 2/6
# 376/376 [==============================] - 7s 18ms/step - loss: 0.6827 - acc: 0.7613 - val_loss: 0.5150 - val_acc: 0.8201
# Epoch 3/6
# 376/376 [==============================] - 8s 22ms/step - loss: 0.6839 - acc: 0.7613 - val_loss: 0.5154 - val_acc: 0.8201
# Epoch 4/6
# 376/376 [==============================] - 7s 18ms/step - loss: 0.6793 - acc: 0.7613 - val_loss: 0.5240 - val_acc: 0.8201
# Epoch 5/6
# 376/376 [==============================] - 9s 25ms/step - loss: 0.6777 - acc: 0.7613 - val_loss: 0.5251 - val_acc: 0.8201
# Epoch 6/6
# 376/376 [==============================] - 8s 20ms/step - loss: 0.6755 - acc: 0.7613 - val_loss: 0.5180 - val_acc: 0.8201

# %%
score = cnn.evaluate(x_test,y_test)
# Out:
# 405/405 [==============================] - 5s 13ms/step - loss: 0.8241 - acc: 0.7019
